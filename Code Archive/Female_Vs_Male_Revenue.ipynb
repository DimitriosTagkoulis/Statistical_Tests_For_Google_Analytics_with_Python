# %%
import pandas as pd
import numpy as np
#libraries for normality tests
from scipy.stats import shapiro
from statsmodels.graphics.gofplots import qqplot
from matplotlib import pyplot

# %%
#import the User Datasets
xls = pd.ExcelFile('Female_Vs_Male_Revenue.xlsx')
Male = pd.read_excel(xls, 'Male')
Female = pd.read_excel(xls, 'Female')

#Remove the dates for ease
Male = Male['Revenue']
Female = Female['Revenue']

#convert datasets into arrays
Male = Male.values
Female = Female.values

#plot both datasets using qqplot to check for normality
qqplot(Male, line='s')
pyplot.show()

qqplot(Female, line='s')
pyplot.show()

# %%
# normality test with Shapiro
stat, p = shapiro(Male)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
    print('Sample looks Gaussian (fail to reject H0)')
else:
    print('Sample does not look Gaussian (reject H0)')

stat, p = shapiro(Female)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
    print('Sample looks Gaussian (fail to reject H0)')
else:
    print('Sample does not look Gaussian (reject H0)')
# Out:
# Statistics=0.455, p=0.000
# Sample does not look Gaussian (reject H0)
# Statistics=0.295, p=0.000
# Sample does not look Gaussian (reject H0)

# %% [markdown]
# ### Not both datasets are normaly distributed non - parametric tests should be used.

# %%
#import ranksums (Wilcoxon-Mann-Whitney (WMW) rank sum test) to test wether the difference between the two datasets is significant
from scipy.stats import ranksums

stat, p = ranksums(Male,Female)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
    print('The difference between the two datasets is not significant (fail to reject H0)')
else:
    print('The difference between the two datasets is significant (reject H0)')
# Out:
# Statistics=0.624, p=0.533
# The difference between the two datasets is not significant (fail to reject H0)

# %% [markdown]
# ### We conclude that the difference between the two datasets is not significant
